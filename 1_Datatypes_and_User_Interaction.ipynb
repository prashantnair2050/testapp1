# %%
# Datatypes ---- Datatype defines the type of the data a variable can hold/maintain :)
# Datatypes ---- 1. Primitive Types
#                2. Collection Types
#
#                          Primitive Types
#                                  |
#    ---------------------------------------------------------------------
#    |                            |                                      |
# Numbers                     String                                  Boolean
#    |
#   ----------------------
#   |          |          |
# Integers  Decimals  Complex
# Out:
# 30

# %%
#Python is a type Inferrerd language
#Type Inference: Assigning datatype automatically based on the value supplied to the variable

num1 = 10

type(num1)
# Out:
# int

# %%
data = "Welcome to Python Programming"
data
# Out:
# 'Welcome to Python Programming'

# %%
data2 = 3+4j
type(data2)
# Out:
# complex

# %%
data3 = "16"
type(data3)
# Out:
# str

# %%
#TypeCasting
#Converting the datatype from one type to another considering  the value in the variable supports the destination datatype
#

int(data3)
# Out:
# 16

# %%
#Boolean
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
#User  Interaction
#Accept user inputs ----> input()
#input() accepts data from user in the form of string!

num1 = int(input("Enter First Number: "))
num2 = int(input("Enter Second Number: "))
result = num1+num2

print("Addition of {} and {} is {}".format(num1,num2,result))
# Out:
# Enter First Number: 2
# Enter Second Number: 3
# Addition of 2 and 3 is 5

# %%
type(num1)
# Out:
# int
